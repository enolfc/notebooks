# %%
import folium

# %%
m = folium.Map(location=[45.5236, 9.6750], tiles="Cartodb Positron", zoom_start=4)

fedcloud_sites = {
    "NCG-INGRID": {"coords": [38.739848, -9.143310]},
    "CESNET": {"coords": [50.101748, 14.390782]},
    "CESGA": {"coords": [42.875837, -8.553310]},
    "IFCA-LCG2": {"coords": [43.471637, -3.802261]},
    "INFN-BARI": {"coords": [41.108769, 16.884660]},
    "INFN-PADOVA": {"coords": [45.352492, 11.949370]},
    "UPV": {"coords": [39.479723, -0.344526]},
    "SCAI": {"coords": [50.749516, 7.203695]},
    "TUBITAK": {"coords": [39.877104, 32.762646]},
    "IN2P3-IRES": {"coords": [48.579069, 7.766455]},
    "100IT": {"coords": [51.407009, -1.327695]},
    "IFIN": {"coords": [44.352820, 26.039455]},
    "LILLE": {"coords": [50.631656, 3.075204]},
    "BITP": {"coords": [50.339397, 30.480950]},
    "DESY": {"coords": [50.339397, 30.480950]},
    "SRCE": {"coords": [45.792222, 15.969507]},
    "CETA": {"coords": [39.458450, -5.880992]},
    "BIFI": {"coords": [41.684562, -0.887055]},
    "Kharkov": {"coords": [50.087662, 36.251762]},
    "CYFRONET": {"coords": [50.068978, 19.90916]},
    #"CLOUD-INFN-CATANIA": {"coords": [37.5, 15.15]}
    #"GWDG": {"coords": [51.562143, 9.970916]},
    # incorporated during ACE
    "GRNET": {"coords": [37.987612, 23.761858], "color": "orange"},
    "GSI-LCG2": {"coords": [49.931493, 8.679360], "color": "orange"},
    "CNAF": {"coords": [44.501135, 11.357439], "color":"orange"},
    "ILIFU": {"coords": [-33.950000, 18.471667], "color":"orange"},
    "CSTCloud": {"coords": [39.910630, 116.335630], "color":"orange"},
    "WALTON": {"coords": [52.253972, -7.188872], "color":"orange"},
    "ELKH-CLOUD": {"coords": [47.49351304262144, 19.0523693341759], "color": "orange"},
    # Check-in tests
    "OTC": {"coords": [51.99030351125569, 11.652566843242683], "color": "green", "icon": "user"},
    "CLoudFerro": {"coords": [52.23510650914357, 21.032037727695432], "color": "green", "icon": "user"},  
    "EODC":  {"coords": [48.17936761521815, 16.395980516861375], "color": "green", "icon": "user"},  
    # in progress 
    "RENAM": {"coords": [47.00079440669263, 28.815644682699673], "color": "purple", "icon": "gear"},
    "ASNET": {"coords": [40.192544792672805, 44.5087426979187], "color": "purple", "icon": "gear"},    
}

for site, info in fedcloud_sites.items():
    color = info.get("color", "blue")
    icon = info.get("icon", "circle")
    folium.Marker(
        location=info["coords"],
        icon=folium.Icon(color=color, icon=icon, prefix='fa'),
    ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
